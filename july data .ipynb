# %%
import pandas as pd

# %%
data = pd.read_csv("idp farmer order data .csv")

data.head()

data.shape


#Update date  for the desired report 
start_date = '2022-07-01'
end_date = '2022-07-21'

mask = (data['creationDate'] > start_date) & (data['creationDate'] <= end_date) 


data = data.loc[mask]


data["creationDate"] = pd.to_datetime(data["creationDate"])  


data = data.sort_values(by="creationDate", ascending=False)


#data.isnull().sum() 

data['creationDate'] = pd.to_datetime(data['creationDate']).dt.date 


#Alsowadetermining the name of the file
data_file_name = 'July Input Platform Data .xlsx'
 
 
#saving the excel
data.to_excel(data_file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
data
# Out:
#                                farmerOrderId  \
# 121989  4c7f31a9-7a92-469c-bc69-4f3a2b0352e7
# 122897  8fe9143e-ad89-4f58-b480-d6bb6fda1e27
# 122356  16fc1dee-843e-4387-80f3-42db7a3958e7
# 18420   c6dcb92e-dd56-4d3e-aa7f-c038ad12f70a
# 35947   73ba8ac0-7678-428b-8651-287c7f7ac575
# ...                                      ...
# 113990  af3cd1c2-839b-44b2-96f4-ac91f188fd16
# 87106   8064b23d-904f-46da-8fc9-0261fe85a5cb
# 134877  3ab5c4fd-9a69-4e1c-9e70-d04a65a3ce0c
# 107757  15b6420a-46cd-4aac-8a24-c5178e35ac20
# 102911  95655037-04c1-4e2c-b4bb-44e6799191c5
#
#                                     branchId creationDate  \
# 121989  42752975-72a6-4395-9df8-3f58092fe804   2022-07-20
# 122897  42752975-72a6-4395-9df8-3f58092fe804   2022-07-20
# 122356  701d21f3-539d-46c7-b57e-176a50aafab1   2022-07-20
# 18420   6e70a8f7-ca67-4e2a-889c-c2f94edc09e8   2022-07-20
# 35947   4a8b0fc0-71dd-4657-8f11-0446c61771c2   2022-07-20
# ...                                      ...          ...
# 113990  c15d6999-652c-4bd3-8fe5-720a7a878a27   2022-07-01
# 87106   c15d6999-652c-4bd3-8fe5-720a7a878a27   2022-07-01
# 134877  c15d6999-652c-4bd3-8fe5-720a7a878a27   2022-07-01
# 107757  c15d6999-652c-4bd3-8fe5-720a7a878a27   2022-07-01
# 102911  c15d6999-652c-4bd3-8fe5-720a7a878a27   2022-07-01
#
#                                        dmaId             dmaName  \
# 121989  a2e2c266-89f7-4615-b865-d15d611e69e6    Wamucii farmcare
# 122897  a2e2c266-89f7-4615-b865-d15d611e69e6    Wamucii farmcare
# 122356  eb8090a0-c1d2-4307-b8cf-ab5c38b7f22a  Stage  Connections
# 18420   a514a431-1373-4a9d-b4e5-3b06284022dc         Alanet shop
# 35947   c645ab53-e896-40dc-9828-80f4b7eff466     Gikaa resources
# ...                                      ...                 ...
# 113990  987a93b5-07d1-420e-a9cf-aba7ad40b6cc    Dic Dic Agrocare
# 87106   987a93b5-07d1-420e-a9cf-aba7ad40b6cc    Dic Dic Agrocare
# 134877  987a93b5-07d1-420e-a9cf-aba7ad40b6cc    Dic Dic Agrocare
# 107757  987a93b5-07d1-420e-a9cf-aba7ad40b6cc    Dic Dic Agrocare
# 102911  987a93b5-07d1-420e-a9cf-aba7ad40b6cc    Dic Dic Agrocare
#
#                                    dmaUserId     farmerName  farmerNumber  \
# 121989  c96ec874-8ac4-4332-87b6-48938dcc2767  254714000659   2.547140e+11
# 122897  c96ec874-8ac4-4332-87b6-48938dcc2767  254717776817   2.547178e+11
# 122356  67a4fed3-ef51-4633-9141-f21a9af8cbea  254727872916   2.547279e+11
# 18420   0ed6b562-4b3d-4c93-bcb3-51a45ebb733e  254742484583   2.547425e+11
# 35947   18e9f624-73e7-4aa7-b2d3-fd879a17bb78  254720885790   2.547209e+11
# ...                                      ...            ...           ...
# 113990  e20c3b75-e2e2-4b18-b1f2-479277462f36  254704690079   2.547047e+11
# 87106   e20c3b75-e2e2-4b18-b1f2-479277462f36  254791989750   2.547920e+11
# 134877  e20c3b75-e2e2-4b18-b1f2-479277462f36  254794109291   2.547941e+11
# 107757  e20c3b75-e2e2-4b18-b1f2-479277462f36  254797563860   2.547976e+11
# 102911  e20c3b75-e2e2-4b18-b1f2-479277462f36  254715340514   2.547153e+11
#
#        farmerOrderStatus  memberNumber modificationDate mpesaTransactionId  \
# 121989          COMPLETE  254714000659              NaN                NaN
# 122897          COMPLETE  254717776817              NaN                NaN
# 122356          COMPLETE  254727872916              NaN                NaN
# 18420           COMPLETE        JYPAPY              NaN                NaN
# 35947           COMPLETE  254720885790              NaN                NaN
# ...                  ...           ...              ...                ...
# 113990          COMPLETE  254704690079              NaN                NaN
# 87106           COMPLETE  254791989750              NaN                NaN
# 134877          COMPLETE  254794109291              NaN                NaN
# 107757          COMPLETE  254797563860              NaN                NaN
# 102911          COMPLETE  254715340514              NaN                NaN
#
#        paymentMethod paymentStatus  \
# 121989          CASH          PAID
# 122897          CASH          PAID
# 122356          CASH          PAID
# 18420           CASH          PAID
# 35947           CASH          PAID
# ...              ...           ...
# 113990          CASH          PAID
# 87106           CASH          PAID
# 134877          CASH          PAID
# 107757          CASH          PAID
# 102911          CASH          PAID
#
#                                                   product  rebates  \
# 121989  [{"M":{"product":{"M":{"selling_price":{"N":"1...      0.0
# 122897  [{"M":{"product":{"M":{"selling_price":{"N":"1...      0.0
# 122356  [{"M":{"product":{"M":{"selling_price":{"S":"9...      0.0
# 18420   [{"M":{"product":{"M":{"selling_price":{"N":"5...      0.0
# 35947   [{"M":{"product":{"M":{"selling_price":{"N":"7...      0.0
# ...                                                   ...      ...
# 113990  [{"M":{"product":{"M":{"selling_price":{"N":"0...      0.0
# 87106   [{"M":{"product":{"M":{"selling_price":{"N":"0...      0.0
# 134877  [{"M":{"product":{"M":{"selling_price":{"N":"0...      0.0
# 107757  [{"M":{"product":{"M":{"selling_price":{"N":"0...      0.0
# 102911  [{"M":{"product":{"M":{"selling_price":{"N":"0...      0.0
#
#        rebateTranId  totalCost
# 121989          NaN      122.0
# 122897          NaN      122.0
# 122356          NaN       97.0
# 18420           NaN      515.0
# 35947           NaN       70.0
# ...             ...        ...
# 113990          NaN        0.0
# 87106           NaN        0.0
# 134877          NaN        0.0
# 107757          NaN        0.0
# 102911          NaN        0.0
#
# [14358 rows x 18 columns]
